# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('bmw.csv')

# Display basic info and first few rows
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         1022 non-null   object
#  1   Library ID     1022 non-null   float64
#  2   Platform       1022 non-null   object
#  3   Brand          1022 non-null   object
#  4   CountryID      1022 non-null   object
#  5   Status         1022 non-null   object
#  6   Date Range     1022 non-null   object
#  7   Caption        1020 non-null   object
#  8   CTA Caption    918 non-null    object
#  9   CTA Button     927 non-null    object
#  10  Platforms      1022 non-null   object
#  11  Ad Link        1022 non-null   object
#  12  Overall Reach  897 non-null    float64
#  13  Gender         896 non-null    object
#  14  Age Range      896 non-null    object
#  15  Segments       897 non-null    object
#  16  Ad Type        1022 non-null   object
# ...
